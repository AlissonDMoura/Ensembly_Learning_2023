# %%
import os
import numpy as np
import random

from sklearn.model_selection import train_test_split

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %% [markdown]
# ### We used this notebook to tune the models for ensembly learning and achieve best results

# %%
import tensorflow as tf

if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TensorFlow")
# Out:
# Please install GPU version of TensorFlow

# %%
dataset_path = 'C:/Users/aliss/OneDrive/Área de Trabalho/last Semester/Industry Project/dataset/Digiface/Test'
datagen = ImageDataGenerator(rescale=1./255,
    validation_split=0.25)

# %%
train_generator = datagen.flow_from_directory(
    dataset_path,target_size=(112, 112),batch_size=8,class_mode='categorical',subset='training')

validation_generator = datagen.flow_from_directory(
    dataset_path, target_size=(112, 112), batch_size=8, class_mode='categorical',subset='validation')
# Out:
# Found 1134 images belonging to 21 classes.
# Found 378 images belonging to 21 classes.

# %%
model = Sequential()

# add convolutional layer with 32 filters and 3x3 kernel size, basic activation and image size and RGB
model.add(Conv2D(32, (7, 7), activation='relu', input_shape=(112, 112, 3)))

# add max pooling layer with 2x2 pool size - complexity of the neural network
model.add(MaxPooling2D((2, 2)))

# add convolutional layer with 64 filters and 3x3 kernel size
model.add(Conv2D(32, (3, 3), activation='relu'))

# add max pooling layer with 2x2 pool size
model.add(MaxPooling2D((2, 2)))

# add flatten layer to convert output to 1D
model.add(Flatten())

# add dense layer with 256 units
model.add(Dense(256, activation='relu'))

# add output layer with 2000 units for multi-class classification
model.add(Dense(21, activation='softmax'))

# compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_generator, epochs=100, validation_data=validation_generator)
# Out:
# Epoch 1/100
# 142/142 [==============================] - 25s 172ms/step - loss: 2.9681 - accuracy: 0.1085 - val_loss: 2.6610 - val_accuracy: 0.2566
# Epoch 2/100
# 142/142 [==============================] - 24s 172ms/step - loss: 1.7630 - accuracy: 0.4921 - val_loss: 1.8644 - val_accuracy: 0.5397
# Epoch 3/100
# 142/142 [==============================] - 24s 172ms/step - loss: 0.6499 - accuracy: 0.8183 - val_loss: 1.8814 - val_accuracy: 0.5344
# Epoch 4/100
# 142/142 [==============================] - 24s 171ms/step - loss: 0.1656 - accuracy: 0.9524 - val_loss: 1.7646 - val_accuracy: 0.6561
# Epoch 5/100
# 142/142 [==============================] - 24s 172ms/step - loss: 0.0412 - accuracy: 0.9921 - val_loss: 1.8260 - val_accuracy: 0.6905
# Epoch 6/100
# 142/142 [==============================] - 24s 171ms/step - loss: 0.0064 - accuracy: 0.9991 - val_loss: 1.8135 - val_accuracy: 0.6958
# Epoch 7/100
# ...

# %%
model = Sequential()

# add convolutional layer with 32 filters and 7x7 kernel size, basic activation and image size and RGB
model.add(Conv2D(32, (7, 7), activation='relu', input_shape=(112, 112, 3)))

# add max pooling layer with 2x2 pool size - complexity of the neural network
model.add(MaxPooling2D((3, 3)))

# add convolutional layer with 32 filters and 3x3 kernel size
model.add(Conv2D(32, (3, 3), activation='relu'))

# add max pooling layer with 2x2 pool size
model.add(MaxPooling2D((2, 2)))

# add flatten layer to convert output to 1D
model.add(Flatten())

# add dense layer with 256 units
model.add(Dense(128, activation='relu'))

# add output layer with 2000 units for multi-class classification
model.add(Dense(20, activation='softmax'))

# compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Epoch 1/10
# 142/142 [==============================] - 18s 118ms/step - loss: 2.9966 - accuracy: 0.0794 - val_loss: 2.8790 - val_accuracy: 0.1164
# Epoch 2/10
# 142/142 [==============================] - 17s 116ms/step - loss: 2.1563 - accuracy: 0.3589 - val_loss: 2.1518 - val_accuracy: 0.3783
# Epoch 3/10
# 142/142 [==============================] - 17s 118ms/step - loss: 1.1126 - accuracy: 0.6702 - val_loss: 1.6945 - val_accuracy: 0.5503
# Epoch 4/10
# 142/142 [==============================] - 17s 119ms/step - loss: 0.5040 - accuracy: 0.8483 - val_loss: 1.7995 - val_accuracy: 0.5873
# Epoch 5/10
# 142/142 [==============================] - 17s 122ms/step - loss: 0.2181 - accuracy: 0.9418 - val_loss: 1.8013 - val_accuracy: 0.5926
# Epoch 6/10
# 142/142 [==============================] - 17s 118ms/step - loss: 0.0860 - accuracy: 0.9841 - val_loss: 1.7308 - val_accuracy: 0.6508
# Epoch 7/10
# ...
